# %%
openai_rg_name = 'OAIResourceGroup'
openai_svc_name = 'MyOpenAIResource'
subscription_id = 'f1ea6ed8-82f3-416d-881b-8b376218bc85'

# %%
# Login to Azure
# !az login
# Out:
# A web browser has been opened at https://login.microsoftonline.com/organizations/oauth2/v2.0/authorize. Please continue the login in the web browser. If no web browser is available or if the web browser fails to open, use device code flow with `az login --use-device-code`.
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "074101a8-2a55-4e54-9b9f-56c83e17cb22",
#     "id": "f1ea6ed8-82f3-416d-881b-8b376218bc85",
#     "isDefault": true,
#     "managedByTenants": [],
#     "name": "gbb-alzeltov",
#     "state": "Enabled",
#     "tenantId": "074101a8-2a55-4e54-9b9f-56c83e17cb22",
#     "user": {
#       "name": "alex@azlabs49.net",
#       "type": "user"
#     }
#   }
# ]
#
# [Survey] Help us improve Azure CLI by sharing your experience. This survey should take about 5 minutes. Run 'az survey' to open in browser. Learn more at https://go.microsoft.com/fwlink/?linkid=2203309

# %%
# !az account set --subscription $subscription_id

# %%
# !az group create --name $openai_rg_name --location southcentralus
# Out:
# {
#   "id": "/subscriptions/f1ea6ed8-82f3-416d-881b-8b376218bc85/resourceGroups/OAIResourceGroup",
#   "location": "southcentralus",
#   "managedBy": null,
#   "name": "OAIResourceGroup",
#   "properties": {
#     "provisioningState": "Succeeded"
#   },
#   "tags": null,
#   "type": "Microsoft.Resources/resourceGroups"
# }

# %% [markdown]
# # Create OpenAI service
# Update -l parameter value for a new endpoint uri

# %%
# Wait until the resource group is created
# Create OpenAI service
# !az cognitiveservices account create -n $openai_svc_name -g $openai_rg_name -l southcentralus --kind OpenAI --sku s0 --subscription $subscription_id
# Out:
# {\ Finished ..
#   "etag": "\"d202207a-0000-0500-0000-63dd6a9b0000\"",
#   "id": "/subscriptions/f1ea6ed8-82f3-416d-881b-8b376218bc85/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource",
#   "identity": null,
#   "kind": "OpenAI",
#   "location": "southcentralus",
#   "name": "MyOpenAIResource",
#   "properties": {
#     "allowedFqdnList": null,
#     "apiProperties": null,
#     "callRateLimit": {
#       "count": null,
#       "renewalPeriod": null,
#       "rules": [
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "openai",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "openai/*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         },
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "default",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         }
#       ]
#     },
#     "capabilities": [
#       {
#         "name": "VirtualNetworks",
#         "value": null
#       },
#       {
#         "name": "MaxFineTuneCount",
#         "value": "100"
#       },
#       {
#         "name": "MaxRunningFineTuneCount",
#         "value": "1"
#       },
#       {
#         "name": "MaxUserFileCount",
#         "value": "50"
#       },
#       {
#         "name": "MaxTrainingFileSize",
#         "value": "100000000"
#       },
#       {
#         "name": "MaxUserFileImportDurationInHours",
#         "value": "1"
#       },
#       {
#         "name": "MaxFineTuneJobDurationInHours",
#         "value": "120"
#       }
#     ],
#     "customSubDomainName": null,
#     "dateCreated": "2023-02-03T20:11:24.1149209Z",
#     "deletionDate": null,
#     "disableLocalAuth": null,
#     "dynamicThrottlingEnabled": null,
#     "encryption": null,
#     "endpoint": "https://southcentralus.api.cognitive.microsoft.com/",
#     "endpoints": {
#       "OpenAI Language Model Instance API": "https://southcentralus.api.cognitive.microsoft.com/"
#     },
#     "internalId": "bee670b606b54796bef7e2ff200b9f04",
#     "isMigrated": false,
#     "migrationToken": null,
#     "networkAcls": null,
#     "privateEndpointConnections": [],
#     "provisioningState": "Succeeded",
#     "publicNetworkAccess": "Enabled",
#     "quotaLimit": null,
#     "restore": null,
#     "restrictOutboundNetworkAccess": null,
#     "scheduledPurgeDate": null,
#     "skuChangeInfo": null,
#     "userOwnedStorage": null
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "sku": {
#     "capacity": null,
#     "family": null,
#     "name": "S0",
#     "size": null,
#     "tier": null
#   },
#   "systemData": {
#     "createdAt": "2023-02-03T20:11:23.762839+00:00",
#     "createdBy": "alex@azlabs49.net",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-02-03T20:11:23.762839+00:00",
#     "lastModifiedBy": "alex@azlabs49.net",
#     "lastModifiedByType": "User"
#   },
#   "tags": null,
#   "type": "Microsoft.CognitiveServices/accounts"
# }

# %%
# !az cognitiveservices account show -n $openai_svc_name -g $openai_rg_name
# Out:
# {
#   "etag": "\"d202207a-0000-0500-0000-63dd6a9b0000\"",
#   "id": "/subscriptions/f1ea6ed8-82f3-416d-881b-8b376218bc85/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource",
#   "identity": null,
#   "kind": "OpenAI",
#   "location": "southcentralus",
#   "name": "MyOpenAIResource",
#   "properties": {
#     "allowedFqdnList": null,
#     "apiProperties": null,
#     "callRateLimit": {
#       "count": null,
#       "renewalPeriod": null,
#       "rules": [
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "openai",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "openai/*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         },
#         {
#           "count": 30.0,
#           "dynamicThrottlingEnabled": null,
#           "key": "default",
#           "matchPatterns": [
#             {
#               "method": "*",
#               "path": "*"
#             }
#           ],
#           "minCount": null,
#           "renewalPeriod": 1.0
#         }
#       ]
#     },
#     "capabilities": [
#       {
#         "name": "VirtualNetworks",
#         "value": null
#       },
#       {
#         "name": "MaxFineTuneCount",
#         "value": "100"
#       },
#       {
#         "name": "MaxRunningFineTuneCount",
#         "value": "1"
#       },
#       {
#         "name": "MaxUserFileCount",
#         "value": "50"
#       },
#       {
#         "name": "MaxTrainingFileSize",
#         "value": "100000000"
#       },
#       {
#         "name": "MaxUserFileImportDurationInHours",
#         "value": "1"
#       },
#       {
#         "name": "MaxFineTuneJobDurationInHours",
#         "value": "120"
#       }
#     ],
#     "customSubDomainName": null,
#     "dateCreated": "2023-02-03T20:11:24.1149209Z",
#     "deletionDate": null,
#     "disableLocalAuth": null,
#     "dynamicThrottlingEnabled": null,
#     "encryption": null,
#     "endpoint": "https://southcentralus.api.cognitive.microsoft.com/",
#     "endpoints": {
#       "OpenAI Language Model Instance API": "https://southcentralus.api.cognitive.microsoft.com/"
#     },
#     "internalId": "bee670b606b54796bef7e2ff200b9f04",
#     "isMigrated": false,
#     "migrationToken": null,
#     "networkAcls": null,
#     "privateEndpointConnections": [],
#     "provisioningState": "Succeeded",
#     "publicNetworkAccess": "Enabled",
#     "quotaLimit": null,
#     "restore": null,
#     "restrictOutboundNetworkAccess": null,
#     "scheduledPurgeDate": null,
#     "skuChangeInfo": null,
#     "userOwnedStorage": null
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "sku": {
#     "capacity": null,
#     "family": null,
#     "name": "S0",
#     "size": null,
#     "tier": null
#   },
#   "systemData": {
#     "createdAt": "2023-02-03T20:11:23.762839+00:00",
#     "createdBy": "alex@azlabs49.net",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-02-03T20:11:23.762839+00:00",
#     "lastModifiedBy": "alex@azlabs49.net",
#     "lastModifiedByType": "User"
#   },
#   "tags": null,
#   "type": "Microsoft.CognitiveServices/accounts"
# }

# %%
# !az cognitiveservices account keys list -n $openai_svc_name -g $openai_rg_name
# Out:
# {
#   "key1": "53831d6a47d84defb3f61912889ff47e",
#   "key2": "097621257f04454385cb7901f4994764"
# }

# %%
# Deploy a model
search_doc_deployment_name = 'curie-search-doc'
search_doc_model = 'text-search-curie-doc-001'
search_query_deployment_name = 'curie-search-query'
search_query_model = 'text-search-curie-query-001'
text_deployment_name = 'text-davinci-002'
text_model = 'text-davinci-002'

# !az cognitiveservices account deployment create -g $openai_rg_name -n $openai_svc_name --deployment-name $search_doc_deployment_name --model-name $search_doc_model --model-version "1"  --model-format OpenAI --scale-settings-scale-type "Standard"
# Out:
# {- Starting ..
#   "etag": "\"a9241fe4-9eba-4233-b2dc-e42c06684d3e\"",
#   "id": "/subscriptions/f1ea6ed8-82f3-416d-881b-8b376218bc85/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource/deployments/curie-search-doc",
#   "name": "curie-search-doc",
#   "properties": {
#     "model": {
#       "format": "OpenAI",
#       "name": "text-search-curie-doc-001",
#       "version": "1"
#     },
#     "provisioningState": "Succeeded",
#     "scaleSettings": {
#       "activeCapacity": null,
#       "capacity": null,
#       "scaleType": "Standard"
#     }
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "systemData": {
#     "createdAt": "2023-02-03T20:12:31.193208+00:00",
#     "createdBy": "alex@azlabs49.net",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-02-03T20:12:31.193208+00:00",
#     "lastModifiedBy": "alex@azlabs49.net",
#     "lastModifiedByType": "User"
#   },
#   "type": "Microsoft.CognitiveServices/accounts/deployments"
# }

# %%
# !az cognitiveservices account deployment create -g $openai_rg_name -n $openai_svc_name --deployment-name $search_query_deployment_name --model-name $search_query_model --model-version "1"  --model-format OpenAI --scale-settings-scale-type "Standard"
# !az cognitiveservices account deployment create -g $openai_rg_name -n $openai_svc_name --deployment-name $text_deployment_name --model-name $text_model --model-version "1"  --model-format OpenAI --scale-settings-scale-type "Standard"
# Out:
# {- Starting ..
#   "etag": "\"0d15a277-5e27-40cc-a8ee-b37a51fe560c\"",
#   "id": "/subscriptions/f1ea6ed8-82f3-416d-881b-8b376218bc85/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource/deployments/curie-search-query",
#   "name": "curie-search-query",
#   "properties": {
#     "model": {
#       "format": "OpenAI",
#       "name": "text-search-curie-query-001",
#       "version": "1"
#     },
#     "provisioningState": "Succeeded",
#     "scaleSettings": {
#       "activeCapacity": null,
#       "capacity": null,
#       "scaleType": "Standard"
#     }
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "systemData": {
#     "createdAt": "2023-02-03T20:12:32.756981+00:00",
#     "createdBy": "alex@azlabs49.net",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-02-03T20:12:32.756981+00:00",
#     "lastModifiedBy": "alex@azlabs49.net",
#     "lastModifiedByType": "User"
#   },
#   "type": "Microsoft.CognitiveServices/accounts/deployments"
# }
# {- Starting ..
#   "etag": "\"e507e3e7-62c0-4216-bd8f-2a0171ec9d43\"",
#   "id": "/subscriptions/f1ea6ed8-82f3-416d-881b-8b376218bc85/resourceGroups/OAIResourceGroup/providers/Microsoft.CognitiveServices/accounts/MyOpenAIResource/deployments/text-davinci-002",
#   "name": "text-davinci-002",
#   "properties": {
#     "model": {
#       "format": "OpenAI",
#       "name": "text-davinci-002",
#       "version": "1"
#     },
#     "provisioningState": "Succeeded",
#     "scaleSettings": {
#       "activeCapacity": null,
#       "capacity": null,
#       "scaleType": "Standard"
#     }
#   },
#   "resourceGroup": "OAIResourceGroup",
#   "systemData": {
#     "createdAt": "2023-02-03T20:12:34.311002+00:00",
#     "createdBy": "alex@azlabs49.net",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-02-03T20:12:34.311002+00:00",
#     "lastModifiedBy": "alex@azlabs49.net",
#     "lastModifiedByType": "User"
#   },
#   "type": "Microsoft.CognitiveServices/accounts/deployments"
# }
